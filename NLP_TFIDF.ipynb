# %%
import pandas as pd
import numpy as np

# %%
fake=pd.read_csv('Fake.csv')
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true=pd.read_csv('True.csv')
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake['subject']
# Out:
# 0               News
# 1               News
# 2               News
# 3               News
# 4               News
#             ...
# 23476    Middle-east
# 23477    Middle-east
# 23478    Middle-east
# 23479    Middle-east
# 23480    Middle-east
# Name: subject, Length: 23481, dtype: object

# %%
fake['subject'].value_counts()
# Out:
# subject
# News               9050
# politics           6841
# left-news          4459
# Government News    1570
# US_News             783
# Middle-east         778
# Name: count, dtype: int64

# %%
true['subject'].value_counts()
# Out:
# subject
# politicsNews    11272
# worldnews       10145
# Name: count, dtype: int64

# %%
# adding category column 
fake['category']=1
true['category']=0

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  category
# 0  December 31, 2017         1
# 1  December 31, 2017         1
# 2  December 30, 2017         1
# 3  December 29, 2017         1
# 4  December 25, 2017         1

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  category
# 0  December 31, 2017          0
# 1  December 29, 2017          0
# 2  December 31, 2017          0
# 3  December 30, 2017          0
# 4  December 29, 2017          0

# %%
#joining the dataset
df=pd.concat([fake,true]).reset_index(drop=True)

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  category
# 0  December 31, 2017         1
# 1  December 31, 2017         1
# 2  December 30, 2017         1
# 3  December 29, 2017         1
# 4  December 25, 2017         1

# %%
df.tail()
# Out:
#                                                    title  \
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 44893  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 44894  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 44895  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 44896  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 44897  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  category
# 44893  August 22, 2017          0
# 44894  August 22, 2017          0
# 44895  August 22, 2017          0
# 44896  August 22, 2017          0
# 44897  August 22, 2017          0

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#setting the plot size
plt.figure(figsize=(6,7))
sns.countplot(df['category'])
plt.legend()
#plt.show()
# Out:
# C:\Users\Prabhu\AppData\Local\Temp\ipykernel_2132\1280915321.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\Prabhu\anaconda3\envs\VEAI\Lib\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline

# Setting the plot size
plt.figure(figsize=(6,7))

# Creating the count plot
sns.countplot(data=df, x='category')

# Displaying the plot
plt.legend()
plt.show()
# Out:
# C:\Users\Prabhu\AppData\Local\Temp\ipykernel_2132\3695136655.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# C:\Users\Prabhu\anaconda3\envs\VEAI\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10,7))

# Creating the count plot
sns.countplot(data=df, x='subject')

# Displaying the plot
plt.legend()
plt.show()
# Out:
# C:\Users\Prabhu\AppData\Local\Temp\ipykernel_2132\4218341942.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df=df[['text','category']]

# %%
df
# Out:
#                                                     text  category
# 0      Donald Trump just couldn t wish all Americans ...         1
# 1      House Intelligence Committee Chairman Devin Nu...         1
# 2      On Friday, it was revealed that former Milwauk...         1
# 3      On Christmas day, Donald Trump announced that ...         1
# 4      Pope Francis used his annual Christmas Day mes...         1
# ...                                                  ...       ...
# 44893  BRUSSELS (Reuters) - NATO allies on Tuesday we...         0
# 44894  LONDON (Reuters) - LexisNexis, a provider of l...         0
# 44895  MINSK (Reuters) - In the shadow of disused Sov...         0
# 44896  MOSCOW (Reuters) - Vatican Secretary of State ...         0
# 44897  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...         0
#
# [44898 rows x 2 columns]

# %%
df.isna()
# Out:
#         text  category
# 0      False     False
# 1      False     False
# 2      False     False
# 3      False     False
# 4      False     False
# ...      ...       ...
# 44893  False     False
# 44894  False     False
# 44895  False     False
# 44896  False     False
# 44897  False     False
#
# [44898 rows x 2 columns]

# %%
df.isna().sum()
# Out:
# text        0
# category    0
# dtype: int64

# %%
#checking for empty string in text column
blanks=[]

for index,text in df['text'].items():
    if text.isspace():
        blanks.append(index)

len(blanks)
# Out:
# 631

# %%
blanks
# Out:
# [10923,
#  11041,
#  11190,
#  11225,
#  11236,
#  11241,
#  11247,
#  11249,
#  11267,
#  11268,
#  11283,
#  11284,
#  11285,
#  11289,
#  11290,
#  11292,
#  11295,
#  11296,
#  11301,
#  11303,
#  11304,
#  11305,
#  11309,
#  11314,
#  11317,
#  11319,
#  11322,
#  11330,
#  11334,
#  11335,
#  11340,
#  11343,
#  11348,
#  11351,
#  11352,
#  11357,
#  11371,
#  11373,
#  11374,
#  11382,
#  11397,
#  11402,
#  11403,
#  11409,
#  11410,
#  11412,
#  11415,
#  11419,
#  11421,
#  11427,
#  11431,
#  11432,
#  11440,
#  11448,
#  11450,
#  11453,
#  11462,
#  11464,
#  11465,
#  11472,
#  11473,
#  11475,
#  11478,
#  11489,
#  11491,
#  11493,
#  11494,
#  11501,
#  11505,
#  11507,
#  11520,
#  11531,
#  11532,
#  11533,
#  11538,
#  11542,
#  11547,
#  11549,
#  11551,
#  11559,
#  11563,
#  11581,
#  11585,
#  11589,
#  11590,
#  11614,
#  11624,
#  11625,
#  11627,
#  11631,
#  11636,
#  11637,
#  11643,
#  11650,
#  11658,
#  11661,
#  11672,
#  11679,
#  11681,
#  11684,
# ...

# %%
df['text'][10923]
# Out:
# ' '

# %%
df['text'][10922]
# Out:
# 'This Congresswoman has a potty mouth and a bitter attitude towards whites. She s a hateful racist who is paranoid that everyone is out to get her. She just tossed baseless accusations at the Trump administration in an appearance on The Washington Post podcast  Cape Up with Jonathan Capehart.  (See our previous report on the interview below.)Here are the lowlights:Waters accused President Trump of colluding with Russia during the 2016 election, without offering evidence.  I believe this President has colluded with the Russians, with the Kremlin, with the oligarchs, perhaps, of Russia to undermine our election systems,  Waters told Capehart. (4:00) The California congresswoman also criticized the Senate investigation into Trump-Russia ties as not credible.  They re not moving fast enough!  she exclaimed. However, she praised the media for their investigations into Trump-Russia ties. (4:35) Waters described Attorney General Jeff Sessions as a  throwback to the days of Jim Crow,  equati
# ...

# %%
df.shape
# Out:
# (44898, 2)

# %%
df.drop(blanks,inplace=True)

# %%
df.shape
# Out:
# (44267, 2)

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import spacy
import re
nlp=spacy.load('en_core_web_sm')

# %%
#!pip install nltk
#!pip install spacy
'''import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')  # Optional, for lemmatizer support'''
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Prabhu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Prabhu\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Prabhu\AppData\Roaming\nltk_data...
# True

# %%
#!python -m spacy download en_core_web_sm

# %%
lemma=WordNetLemmatizer()

# %%
#stopwords of spacy
list1=nlp.Defaults.stop_words
print(len(list1))

#stopwords of nltk
list2=stopwords.words('english')
print(len(list2))

Stopwords=set((set(list1)|set(list2)))
print(len(Stopwords))
# Out:
# 326
# 179
# 382

# %%
def clean_text(text):
    string=""
    text=text.lower()
    text=re.sub(r"i'm",'i am',text)
    text=re.sub(r"he's",'he is',text)
    text=re.sub(r"she's",'she is',text)
    text=re.sub(r"that's",'that is',text)
    text=re.sub(r"what's",'what is',text)
    text=re.sub(r"where's",'where is',text)
    text=re.sub(r"\'ll",'will',text)
    text=re.sub(r"\'ve",'have',text)
    text=re.sub(r"\'re",'are',text)
    text=re.sub(r"\'d",'would',text)
    text=re.sub(r"won't",'will not',text)
    text=re.sub(r"can't",'can not',text)
    text=re.sub(r"[-()\"!@#$%^&*{}?.,:]",' ',text)
    text=re.sub(r"\s+",' ',text)
    text=re.sub(r"[^A-Za-z0-9]+",' ',text)
    for word in text.split():
        if word not in Stopwords:
            string+=lemma.lemmatize(word)+' '

    return string

# %%
df['text'][10]
# Out:
# "A centerpiece of Donald Trump s campaign, and now his presidency, has been his white supremacist ways. That is why so many of the public feuds he gets into involve people of color. One of his favorite targets, is, of course, the players in the National Football League who dare to exercise their First Amendment rights by kneeling during the national anthem in protest of racist police brutality. Well, there is one person who has figured out that racism is bad for business, even if it did get the orange overlord elected: The founder of the pizza chain Papa John s.This is a man who has never been on the right side of history on any number of issues, and plus his pizza sucks. But, when he decided to complain about the players protesting, his sales really dropped. Turns out racism doesn t pay, and we all know that corporations are all about the bottom line. Therefore, Papa John Schnatter will no longer be CEO of the hack pizza chain.BREAKING: Papa John's founder John Schnatter to step dow
# ...

# %%
clean_text(df['text'][10])
# Out:
# 'centerpiece donald trump campaign presidency white supremacist way public feud get involve people color favorite target course player national football league dare exercise amendment right kneeling national anthem protest racist police brutality person figured racism bad business orange overlord elected founder pizza chain papa john man right history number issue plus pizza suck decided complain player protesting sale dropped turn racism pay know corporation line papa john schnatter longer ceo hack pizza chain breaking papa john founder john schnatter step ceo announcement come week criticized nfl protest ap business news apbusiness december 21 2017the thing people certainly allowed political opinion realize opinion come dire consequence especially business trying garner sale support people presume goal ceo know pressure shareholder public outcry boycott nfl stepping right know gone future ceo run company inclusive diverse fabric america guiding symbol nation statue liberty bigot li
# ...

# %%
#Cleaning the entire data set
df['text']=df['text'].apply(clean_text)

# %%
df['text']
# Out:
# 0        donald trump wish american happy new year leav...
# 1        house intelligence committee chairman devin nu...
# 2        friday revealed milwaukee sheriff david clarke...
# 3        christmas day donald trump announced work foll...
# 4        pope francis annual christmas day message rebu...
#                                ...
# 44893    brussels reuters nato ally tuesday welcomed pr...
# 44894    london reuters lexisnexis provider legal regul...
# 44895    minsk reuters shadow disused soviet era factor...
# 44896    moscow reuters vatican secretary state cardina...
# 44897    jakarta reuters indonesia buy 11 sukhoi fighte...
# Name: text, Length: 44267, dtype: object

# %%
from wordcloud import WordCloud

# %%
#!pip install wordcloud

# %%
'''#wordcloud for true news
plt.figure(figsize=(20,20))
wc=WordCloud(max_words=500,height=800,width=1600).generate(" ".join(df[df.category==0].text))
plt.axis('off')
plt.imshow(wc,interpolation='bilinear')'''

# %%
# Check for inline plotting
#%matplotlib inline

# Generate the word cloud for true news
plt.figure(figsize=(20, 20))
wc = WordCloud(max_words=500, height=800, width=1600, background_color='white').generate(" ".join(df[df.category == 0].text))
plt.axis('off')
plt.imshow(wc, interpolation='bilinear')
plt.show()  # Ensure .show() is used to render the image

# %%
from PIL import Image

# %%
#''' thumb=r'C:\Users\Prabhu\Pictures\thumbs_up.png'
#icon=Image.open(thumb)
#mask=Image.new(mode='RGB',size=icon.size,color=(255,255,255))
#mask.paste(icon,box=icon)
#rgb_array=np.array(mask) '''

# %%
from PIL import Image
import numpy as np

# Open the image
thumb = r'C:\Users\Prabhu\Pictures\thumbsup.png'
icon = Image.open(thumb)

# Ensure the mask has an RGBA mode if the icon has transparency
mask = Image.new(mode='RGB', size=icon.size, color=(255, 255, 255, 0))  # '0' for full transparency

# Use the alpha channel of icon as the mask for transparency if it exists
#mask.paste(icon, (0, 0), icon if icon.mode == 'RGBA' else None)
mask.paste(icon,box=icon)
# Convert the mask to an RGB array if needed
rgb_array = np.array(mask.convert('RGB'))

# Check the result
#mask.show()

# %%
# Generate the word cloud for true news
plt.figure(figsize=(10, 10))
wc = WordCloud(mask=rgb_array,max_words=2000, height=800, width=1600).generate(" ".join(df[df.category == 0].text))
plt.axis('off')
plt.imshow(wc, interpolation='bilinear')
plt.show()

# %%
thumb = r'C:\Users\Prabhu\Pictures\skull4.jpg'
icon = Image.open(thumb)

# Ensure the mask has an RGBA mode if the icon has transparency
mask = Image.new(mode='RGB', size=icon.size, color=(255, 255, 255, 0))  # '0' for full transparency

# Use the alpha channel of icon as the mask for transparency if it exists
mask.paste(icon, (0, 0), icon if icon.mode == 'RGBA' else None)
#mask.paste(icon,box=icon)
# Convert the mask to an RGB array if needed
rgb_array = np.array(mask.convert('RGB'))

# %%
plt.figure(figsize=(20, 20))
wc = WordCloud(mask=rgb_array,max_words=500, height=800, width=1600).generate(" ".join(df[df.category == 1].text))
plt.axis('off')
plt.imshow(wc, interpolation='bilinear')
plt.show()

# %%
#model building
from sklearn.model_selection import train_test_split
X=df['text']
y=df['category']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train[10]
# Out:
# 'centerpiece donald trump campaign presidency white supremacist way public feud get involve people color favorite target course player national football league dare exercise amendment right kneeling national anthem protest racist police brutality person figured racism bad business orange overlord elected founder pizza chain papa john man right history number issue plus pizza suck decided complain player protesting sale dropped turn racism pay know corporation line papa john schnatter longer ceo hack pizza chain breaking papa john founder john schnatter step ceo announcement come week criticized nfl protest ap business news apbusiness december 21 2017the thing people certainly allowed political opinion realize opinion come dire consequence especially business trying garner sale support people presume goal ceo know pressure shareholder public outcry boycott nfl stepping right know gone future ceo run company inclusive diverse fabric america guiding symbol nation statue liberty bigot li
# ...

# %%
y_train[10]
# Out:
# np.int64(1)

# %%
X_test[18180]
# Out:
# 'immediately following president trump inauguration liberal prime minister justin trudeau took twitter invite america refugee illegal immigrant canada meant jab new president promised tougher illegal alien cross border unvetted poorly vetted refugee coming terror hotbed nation guest taxpaying american look like trudeau bitten little chew forced send troop northern canada border response overwhelming flow asylum seeker canada canadian taxpayer paying price forced house feed clothe provide free education illegal alien asylum seeker coming fear allowed stay tougher guideline trump administration working place canadian citizen surely feel safe huge increase illegal border crossing proper documentation nation origin illegal refugee flooding 49th parallel america illegally cross canada according rebel medium report organized effort american cab company greyhound canadian border agent working help loosely vetted illegal fake refugee cross border canada watch incredible investigative report 
# ...

# %%
y_test[18180]
# Out:
# np.int64(1)

# %%
#TFIDF Vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
vector=TfidfVectorizer()
X_train_tfidf=vector.fit_transform(X_train)

# %%
print(X_train_tfidf)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 4425864 stored elements and shape (29658, 95308)>
#   Coords	Values
#   (0, 24740)	0.04026858850645232
#   (0, 11115)	0.038816664535092714
#   (0, 9266)	0.03973176056938726
#   (0, 34716)	0.07073718573579316
#   (0, 52211)	0.054807259931904856
#   (0, 71951)	0.05784571757028958
#   (0, 64314)	0.021990857162681666
#   (0, 10657)	0.0871720107573217
#   (0, 80703)	0.18181879156343372
#   (0, 32126)	0.03882562955660746
#   (0, 88607)	0.04427436589140433
#   (0, 83602)	0.04565994026176609
#   (0, 77681)	0.0518829778182899
#   (0, 50521)	0.02936991613797751
#   (0, 41387)	0.019652409932071273
#   (0, 44261)	0.0880238135208179
#   (0, 14379)	0.026881311707948524
#   (0, 12547)	0.03485672428093034
#   (0, 79270)	0.12014070815442017
#   (0, 46765)	0.11973308708343579
#   (0, 22967)	0.12143379021848894
#   (0, 50517)	0.11653846254925464
#   (0, 31357)	0.15444289710575318
#   (0, 68504)	0.12146324094643259
# ...

# %%
print(X_train_tfidf[0][0])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 193 stored elements and shape (1, 95308)>
#   Coords	Values
#   (0, 24740)	0.04026858850645232
#   (0, 11115)	0.038816664535092714
#   (0, 9266)	0.03973176056938726
#   (0, 34716)	0.07073718573579316
#   (0, 52211)	0.054807259931904856
#   (0, 71951)	0.05784571757028958
#   (0, 64314)	0.021990857162681666
#   (0, 10657)	0.0871720107573217
#   (0, 80703)	0.18181879156343372
#   (0, 32126)	0.03882562955660746
#   (0, 88607)	0.04427436589140433
#   (0, 83602)	0.04565994026176609
#   (0, 77681)	0.0518829778182899
#   (0, 50521)	0.02936991613797751
#   (0, 41387)	0.019652409932071273
#   (0, 44261)	0.0880238135208179
#   (0, 14379)	0.026881311707948524
#   (0, 12547)	0.03485672428093034
#   (0, 79270)	0.12014070815442017
#   (0, 46765)	0.11973308708343579
#   (0, 22967)	0.12143379021848894
#   (0, 50517)	0.11653846254925464
#   (0, 31357)	0.15444289710575318
#   (0, 68504)	0.12146324094643259
# ...

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train_tfidf, y_train)

X_test_tfidf = vector.transform(X_test)
predictions = clf.predict(X_test_tfidf)

# %%
from sklearn.metrics import classification_report
from sklearn import metrics
report=classification_report(y_test, predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93      7047
#            1       0.93      0.94      0.94      7562
#
#     accuracy                           0.93     14609
#    macro avg       0.93      0.93      0.93     14609
# weighted avg       0.93      0.93      0.93     14609

# %%
print(X_train_tfidf.shape)
# Out:
# (29658, 95308)

# %%
print(X_train_tfidf[0].toarray())  # Convert row 0 to dense and print
# Out:
# [[0. 0. 0. ... 0. 0. 0.]]

# %%
print(X_train_tfidf[0, 0])  # Access element at (0, 0)
# Out:
# 0.0

# %%
from sklearn.svm import LinearSVC
Clf=LinearSVC()
model=Clf.fit(X_train_tfidf,y_train)

# %%
X_train[10]
# Out:
# 'centerpiece donald trump campaign presidency white supremacist way public feud get involve people color favorite target course player national football league dare exercise amendment right kneeling national anthem protest racist police brutality person figured racism bad business orange overlord elected founder pizza chain papa john man right history number issue plus pizza suck decided complain player protesting sale dropped turn racism pay know corporation line papa john schnatter longer ceo hack pizza chain breaking papa john founder john schnatter step ceo announcement come week criticized nfl protest ap business news apbusiness december 21 2017the thing people certainly allowed political opinion realize opinion come dire consequence especially business trying garner sale support people presume goal ceo know pressure shareholder public outcry boycott nfl stepping right know gone future ceo run company inclusive diverse fabric america guiding symbol nation statue liberty bigot li
# ...

# %%
from sklearn.pipeline import Pipeline
text_clf=Pipeline([('tfidf',TfidfVectorizer()),('clf',LinearSVC())])
text_clf.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LinearSVC())])

# %%
predict=text_clf.predict(X_test)

# %%
from sklearn.metrics import classification_report
from sklearn import metrics
report=classification_report(y_test, predict)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7047
#            1       0.99      0.99      0.99      7562
#
#     accuracy                           0.99     14609
#    macro avg       0.99      0.99      0.99     14609
# weighted avg       0.99      0.99      0.99     14609

# %%
print(metrics.accuracy_score(y_test,predict))
# Out:
# 0.9932918064206996

# %%
print(metrics.confusion_matrix(y_test,predict))
# Out:
# [[7000   47]
#  [  51 7511]]

# %%
# Example using a single sample text from your original dataset
text_clf.predict(X_train[[10]])
# 1 mwans Fake & 0 menas True
# Out:
# array([1])
