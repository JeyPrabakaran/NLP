# %%
import pandas as pd

# %%
#df = pd.read_csv("mabel.txt",header=None,error_bad_lines=False,encoding='utf8')

# %%
#df = pd.read_csv("Whatsppp_chat.txt", header=None, on_bad_lines='skip', encoding='utf8')
df = pd.read_csv("processed.csv")

# %%
df.head(20)
# Out:
#         Date        Time           Name  \
# 0    10/4/20    9:40 PM      Suganya tn
# 1    10/4/20   11:18 PM      Suganya tn
# 2    10/5/20    5:31 AM    hameedfemina
# 3    10/5/20    5:32 AM    hameedfemina
# 4    10/5/20    5:32 AM    hameedfemina
# 5    10/5/20    5:32 AM    hameedfemina
# 6    10/5/20    5:32 AM    hameedfemina
# 7    10/5/20    5:36 AM    hameedfemina
# 8    10/5/20    5:37 AM    hameedfemina
# 9    10/7/20    7:39 PM    hameedfemina
# 10   10/8/20    5:39 AM    hameedfemina
# 11   10/8/20    5:39 AM    hameedfemina
# 12   10/8/20    8:11 AM      Suganya tn
# 13  10/17/20   12:35 PM    hameedfemina
# 14  10/17/20   12:36 PM    hameedfemina
# 15  10/17/20   12:37 PM    hameedfemina
# 16  10/17/20   12:37 PM    hameedfemina
# 17  10/17/20   12:37 PM    hameedfemina
# 18  10/17/20    3:22 PM      Suganya tn
# 19  10/18/20   11:26 AM    hameedfemina
#
#                                                  Text  \
# 0                        Is that yoga class good Femi
# 1    Preksha from jeeva parivardhanam yoga only u ...
# 2                                         89044 91142
# 3                        This person name is Shashank
# 4                      He s also one of the organizer
# 5                                      U can ping hin
# 6                                                 Him
# 7                            Join this this is useful
# 8    Only thing is need to wake up early. 1 week y...
# 9                                           Namaste 🙏
# 10                           It is very good  for eye
# 11                          Kids can also follow this
# 12                                  Ok ma thanks sure
# 13                                               Sugu
# 14   I got slight pain from thought to till chess ...
# 15   Technition told X-ray a fine ECG is having sl...
# 16   Eve 5 clk only doctor will be back to check t...
# 17                                           Worried.
# 18                Will check with him ma. Don't worry
# 19                           You deleted this message
#
#                                                scores  compound  Negtive  \
# 0   {'neg': 0.0, 'neu': 0.633, 'pos': 0.367, 'comp...    0.4404    0.000
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 4   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 7   {'neg': 0.0, 'neu': 0.37, 'pos': 0.63, 'compou...    0.6249    0.000
# 8   {'neg': 0.144, 'neu': 0.746, 'pos': 0.109, 'co...   -0.1779    0.144
# 9   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 10  {'neg': 0.0, 'neu': 0.61, 'pos': 0.39, 'compou...    0.4927    0.000
# 11  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 12  {'neg': 0.0, 'neu': 0.119, 'pos': 0.881, 'comp...    0.7506    0.000
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 14  {'neg': 0.069, 'neu': 0.931, 'pos': 0.0, 'comp...   -0.2846    0.069
# 15  {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'comp...    0.2023    0.000
# 16  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 17  {'neg': 1.0, 'neu': 0.0, 'pos': 0.0, 'compound...   -0.2960    1.000
# 18  {'neg': 0.0, 'neu': 0.714, 'pos': 0.286, 'comp...    0.3412    0.000
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
#
#     Postive  Neutral comp_score  Topic
# 0     0.367    0.633        pos      4
# 1     0.000    1.000        pos      4
# 2     0.000    1.000        pos      0
# 3     0.000    1.000        pos      4
# 4     0.000    1.000        pos      0
# 5     0.000    1.000        pos      0
# 6     0.000    1.000        pos      0
# 7     0.630    0.370        pos      0
# 8     0.109    0.746        neg      4
# 9     0.000    1.000        pos      0
# 10    0.390    0.610        pos      2
# 11    0.000    1.000        pos      0
# 12    0.881    0.119        pos      2
# 13    0.000    1.000        pos      0
# 14    0.000    0.931        neg      3
# 15    0.184    0.816        pos      3
# 16    0.000    1.000        pos      2
# 17    0.000    0.000        neg      4
# 18    0.286    0.714        pos      2
# 19    0.000    1.000        pos      4

# %%
df=df.drop(0)

# %%
df.columns=['date','chat']

# %%
time=df['chat'].str.split('-',n=1,expand=True)
time.columns=['time','namechat']
name=time['namechat'].str.split(':',n=1,expand=True)
name.head()
# Out:
#                   0                                1
# 1   Mabel Infoziant   Hi this is Mabel we just spoke
# 2   Mabel Infoziant            What’s your full name
# 3               AR❤                   Ramisha Rani K
# 4   Mabel Infoziant                               Ok
# 5   Mabel Infoziant           ramisharanik@gmail.com

# %%
name.columns=['name','chat']
name.head()
# Out:
#                name                             chat
# 1   Mabel Infoziant   Hi this is Mabel we just spoke
# 2   Mabel Infoziant            What’s your full name
# 3               AR❤                   Ramisha Rani K
# 4   Mabel Infoziant                               Ok
# 5   Mabel Infoziant           ramisharanik@gmail.com

# %%
#df=df.drop('chat')
df['time']=time['time']
df['name']=name['name']
df['chat']=name['chat']
df.head()
# Out:
#        date                             chat       time              name
# 1  05/12/19   Hi this is Mabel we just spoke   1:42 pm    Mabel Infoziant
# 2  05/12/19            What’s your full name   1:42 pm    Mabel Infoziant
# 3  05/12/19                   Ramisha Rani K   1:42 pm                AR❤
# 4  05/12/19                               Ok   1:42 pm    Mabel Infoziant
# 5  05/12/19           ramisharanik@gmail.com   1:42 pm    Mabel Infoziant

# %%
df=df[['date','time','name','chat']]
df.head()
# Out:
#        date       time              name                             chat
# 1  05/12/19   1:42 pm    Mabel Infoziant   Hi this is Mabel we just spoke
# 2  05/12/19   1:42 pm    Mabel Infoziant            What’s your full name
# 3  05/12/19   1:42 pm                AR❤                   Ramisha Rani K
# 4  05/12/19   1:42 pm    Mabel Infoziant                               Ok
# 5  05/12/19   1:42 pm    Mabel Infoziant           ramisharanik@gmail.com

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 1 to 50
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    50 non-null     object
#  1   time    50 non-null     object
#  2   name    50 non-null     object
#  3   chat    50 non-null     object
# dtypes: object(4)
# memory usage: 1.7+ KB

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dataset=df

# %%
dataset.head()
# Out:
#        date       time              name                             chat
# 1  05/12/19   1:42 pm    Mabel Infoziant   Hi this is Mabel we just spoke
# 2  05/12/19   1:42 pm    Mabel Infoziant            What’s your full name
# 3  05/12/19   1:42 pm                AR❤                   Ramisha Rani K
# 4  05/12/19   1:42 pm    Mabel Infoziant                               Ok
# 5  05/12/19   1:42 pm    Mabel Infoziant           ramisharanik@gmail.com

# %%
dataset.dropna(inplace=True)
dataset.head()
# Out:
#        date       time              name                             chat
# 1  05/12/19   1:42 pm    Mabel Infoziant   Hi this is Mabel we just spoke
# 2  05/12/19   1:42 pm    Mabel Infoziant            What’s your full name
# 3  05/12/19   1:42 pm                AR❤                   Ramisha Rani K
# 4  05/12/19   1:42 pm    Mabel Infoziant                               Ok
# 5  05/12/19   1:42 pm    Mabel Infoziant           ramisharanik@gmail.com

# %%
# Save DataFrame as a text file
# Save the preprocessed DataFrame as a CSV file
dataset.to_csv('preprocessed_chat.csv', index=False, encoding='utf-8')

# %%
sid = SentimentIntensityAnalyzer()

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Prabhu\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
senti=sid.polarity_scores(dataset['chat'][4])
senti
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}

# %%
def sentimentalAnalysis(data,columnname):
        
        #downloading vader_lexicon for the process
        import matplotlib.pyplot as plt
        import seaborn as sns
        "Importing Necessary Packeage"
        from nltk.sentiment.vader import SentimentIntensityAnalyzer
        sid = SentimentIntensityAnalyzer()
        
        "Deleting null pr empty value"
        data.dropna(inplace=True)
        
        "Checking for a comment"
        #sid.polarity_scores(data[columnname][93])
        
        "Creating respective columns"
        
        data['scores'] = data[columnname].apply(lambda commentText: sid.polarity_scores(commentText))
        data['compound']  = data['scores'].apply(lambda score_dict: score_dict['compound'])
        data['Negtive']  = data['scores'].apply(lambda score_dict: score_dict['neg'])
        data['Postive']  = data['scores'].apply(lambda score_dict: score_dict['pos'])
        data['Neutral']  = data['scores'].apply(lambda score_dict: score_dict['neu'])
        
        "Creating final pos or neg using compound score"
        data['comp_score'] = data['compound'].apply(lambda c: 'pos' if c >=0 else 'neg')
        plt.clf()
        #comp=sns.countplot(x = 'comp_score', hue = 'Name', data = data, palette = 'magma')
        #comp.figure.savefig("date_charts.png")
        "Checking how many pos and neg"
        posneg=pd.DataFrame(data['comp_score'].value_counts())
        return posneg,data

# %%
pos,data_Senti=sentimentalAnalysis(dataset,columnname='chat')

# %%
pos
# Out:
#             count
# comp_score
# pos            48
# neg             2

# %%
print(type(pos))
print(pos.shape if hasattr(pos, 'shape') else len(pos))
print(pos[:5])  # Check the first few elements
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (2, 1)
#             count
# comp_score
# pos            48
# neg             2

# %%
import numpy as np
pos = np.ravel(pos)
pos
# Out:
# array([48,  2])

# %%
print(len(dataset['chat']), len(pos))
# Out:
# 50 2

# %%
data_Senti
# Out:
#         date        time              name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# 22  05/12/19    4:44 pm    Mabel Infoziant
# 23  05/12/19    4:48 pm                AR❤
# 24  05/12/19    8:07 pm                AR❤
# 25  08/12/19   10:45 pm    Mabel Infoziant
# 26  08/12/19   11:52 pm                AR❤
# 27  08/12/19   11:55 pm                AR❤
# 28  09/12/19   12:09 pm                AR❤
# 29  09/12/19   12:13 pm    Mabel Infoziant
# 30  09/12/19   12:23 pm    Mabel Infoziant
# 31  09/12/19   12:25 pm                AR❤
# 32  09/12/19   12:26 pm                AR❤
# 33  09/12/19   12:26 pm                AR❤
# 34  09/12/19   12:28 pm                AR❤
# 35  09/12/19   12:28 pm                AR❤
# 36  09/12/19   12:29 pm                AR❤
# 37  09/12/19   12:41 pm    Mabel Infoziant
# 38  09/12/19   12:42 pm                AR❤
# 39  10/12/19    7:59 am    Mabel Infoziant
# 40  10/12/19    8:00 am    Mabel Infoziant
# 41  10/12/19    8:55 am                AR❤
# 42  12/12/19    2:26 pm    Mabel Infoziant
# 43  15/12/19    8:22 pm                AR❤
# 44  15/12/19    8:40 pm    Mabel Infoziant
# 45  15/12/19    8:40 pm                AR❤
# 46  18/12/19    3:09 pm                AR❤
# 47  18/12/19    3:09 pm                AR❤
# 48  18/12/19    3:11 pm    Mabel Infoziant
# 49  18/12/19    3:11 pm    Mabel Infoziant
# 50  18/12/19    3:12 pm                AR❤
#
#                                                  chat  \
# 1                      Hi this is Mabel we just spoke
# 2                               What’s your full name
# 3                                      Ramisha Rani K
# 4                                                  Ok
# 5                              ramisharanik@gmail.com
# 6                                      Your email Id?
# 7                                             Yes Mam
# 8      I will send 2 abstracts for u to start working
# 9                                            Yeah mam
# 10                   Give me the list that u have too
# 11   Send me cbe office address and phone number I...
# 12    Yeah Mam within Evening I will forward you mam.
# 13   Tomorrow I have to visit the office.yet not I...
# 14                                                 ok
# 15   send the details of office location once u ge...
# 16   Sure mam. Soon I will share details with you mam
# 17   I have read the Abstract mam. We can do mam. ...
# 18   I think Vignesh has the data set will ask him...
# 19                          I have sent the abstracts
# 20                                             Ok mam
# 21   I have read both the abstract mam. We can do ...
# 22   Yes we need to ya about amount and all other ...
# 23                                          Sure mam.
# 24                                  Shall I call mam?
# 25         Hi I was at church couldn’t take your call
# 26                                         It's k mam
# 27   Just to know the tomorrow plan mam.will see t...
# 28                    Mam can u send Vignesh number??
# 29           Vignesh ML Infoziant.vcf (file attached)
# 30                           I was in a meeting sorry
# 31                                    Can I cal u mam
# 32   Waiting for u r finalization of rates for our...
# 33   If we finiliaze I can work with full involvem...
# 34   So what ever may be ..if you think your are c...
# 35                           You deleted this message
# 36                                     Do the needful
# 37   No ma please hold I am in a hot meeting with ...
# 38                                     Ok mam thank u
# 39   Ramisha we need to talk today i will call u a...
# 40     Be ready to discuss about the ML titles u have
# 41                                           Okay mam
# 42                                                 ok
# 43                                    Mam are u free?
# 44   Am at church can call very late or tomorrow only
# 45   Kk mam. I will ask Arun brother. Small doubt ...
# 46                                             Hi mam
# 47                                   Any updates mam?
# 48     U might have to start on the WhatsApp analysis
# 49            There is one project that got committed
# 50                                           Kk mam👍🏻
#
#                                                scores  compound  Negtive  \
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 4   {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 5   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 6   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 7   {'neg': 0.0, 'neu': 0.27, 'pos': 0.73, 'compou...    0.4019    0.000
# 8   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 9   {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 10  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 11  {'neg': 0.0, 'neu': 0.915, 'pos': 0.085, 'comp...    0.0772    0.000
# 12  {'neg': 0.0, 'neu': 0.761, 'pos': 0.239, 'comp...    0.2960    0.000
# 13  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 14  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 15  {'neg': 0.0, 'neu': 0.896, 'pos': 0.104, 'comp...    0.3612    0.000
# 16  {'neg': 0.0, 'neu': 0.609, 'pos': 0.391, 'comp...    0.5423    0.000
# 17  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 18  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 19  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 20  {'neg': 0.0, 'neu': 0.312, 'pos': 0.688, 'comp...    0.2960    0.000
# 21  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 22  {'neg': 0.0, 'neu': 0.838, 'pos': 0.162, 'comp...    0.4019    0.000
# 23  {'neg': 0.0, 'neu': 0.303, 'pos': 0.697, 'comp...    0.3182    0.000
# 24  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 25  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 26  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 27  {'neg': 0.0, 'neu': 0.775, 'pos': 0.225, 'comp...    0.4404    0.000
# 28  {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'comp...    0.1680    0.000
# 29  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 30  {'neg': 0.302, 'neu': 0.698, 'pos': 0.0, 'comp...   -0.0772    0.302
# 31  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 32  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 33  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 34  {'neg': 0.0, 'neu': 0.875, 'pos': 0.125, 'comp...    0.5106    0.000
# 35  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 36  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 37  {'neg': 0.174, 'neu': 0.736, 'pos': 0.089, 'co...   -0.2960    0.174
# 38  {'neg': 0.0, 'neu': 0.175, 'pos': 0.825, 'comp...    0.5719    0.000
# 39  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 40  {'neg': 0.0, 'neu': 0.762, 'pos': 0.238, 'comp...    0.3612    0.000
# 41  {'neg': 0.0, 'neu': 0.345, 'pos': 0.655, 'comp...    0.2263    0.000
# 42  {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound...    0.2960    0.000
# 43  {'neg': 0.0, 'neu': 0.377, 'pos': 0.623, 'comp...    0.5106    0.000
# 44  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 45  {'neg': 0.111, 'neu': 0.619, 'pos': 0.27, 'com...    0.5574    0.111
# 46  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 47  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 48  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...    0.0000    0.000
# 49  {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'comp...    0.2732    0.000
# 50  {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'comp...    0.3612    0.000
#
#     Postive  Neutral comp_score
# 1     0.000    1.000        pos
# 2     0.000    1.000        pos
# 3     0.000    1.000        pos
# 4     1.000    0.000        pos
# 5     0.000    1.000        pos
# 6     0.000    1.000        pos
# 7     0.730    0.270        pos
# 8     0.000    1.000        pos
# 9     0.688    0.312        pos
# 10    0.000    1.000        pos
# 11    0.085    0.915        pos
# 12    0.239    0.761        pos
# 13    0.000    1.000        pos
# 14    1.000    0.000        pos
# 15    0.104    0.896        pos
# 16    0.391    0.609        pos
# 17    0.000    1.000        pos
# 18    0.000    1.000        pos
# 19    0.000    1.000        pos
# 20    0.688    0.312        pos
# 21    0.000    1.000        pos
# 22    0.162    0.838        pos
# 23    0.697    0.303        pos
# 24    0.000    1.000        pos
# 25    0.000    1.000        pos
# 26    0.000    1.000        pos
# 27    0.225    0.775        pos
# 28    0.293    0.707        pos
# 29    0.000    1.000        pos
# 30    0.000    0.698        neg
# 31    0.000    1.000        pos
# 32    0.000    1.000        pos
# 33    0.000    1.000        pos
# 34    0.125    0.875        pos
# 35    0.000    1.000        pos
# 36    0.000    1.000        pos
# 37    0.089    0.736        neg
# 38    0.825    0.175        pos
# 39    0.000    1.000        pos
# 40    0.238    0.762        pos
# 41    0.655    0.345        pos
# 42    1.000    0.000        pos
# 43    0.623    0.377        pos
# 44    0.000    1.000        pos
# 45    0.270    0.619        pos
# 46    0.000    1.000        pos
# 47    0.000    1.000        pos
# 48    0.000    1.000        pos
# 49    0.259    0.741        pos
# 50    0.714    0.286        pos

# %%
# Ensure sentiment analysis outputs match the input dataset
pos, data_Senti = sentimentalAnalysis(dataset, columnname='chat')

# Check and resolve length mismatch
if isinstance(pos, pd.DataFrame):
    # Select the correct column containing sentiment data
    pos = pos['count'].tolist()  # Replace 'Sentiment' with the actual column name if different

if len(pos) != len(dataset['chat']):
    print(f"Mismatch: len(pos)={len(pos)}, len(chat)={len(dataset['chat'])}")
    pos = pos + ['Neutral'] * (len(dataset['chat']) - len(pos))  # Pad with 'Neutral'

# Create the DataFrame
data_Senti = pd.DataFrame({
    'chat': dataset['chat'],  # Original text
    'Sentiment': pos          # Sentiment classifications
})

# Display the sentiment counts
print(data_Senti['Sentiment'].value_counts())
# Out:
# Mismatch: len(pos)=2, len(chat)=50
# Sentiment
# Neutral    48
# 48          1
# 2           1
# Name: count, dtype: int64

# %%
data_Senti.head
# Out:
# <bound method NDFrame.head of                                                  chat Sentiment
# 1                      Hi this is Mabel we just spoke        48
# 2                               What’s your full name         2
# 3                                      Ramisha Rani K   Neutral
# 4                                                  Ok   Neutral
# 5                              ramisharanik@gmail.com   Neutral
# 6                                      Your email Id?   Neutral
# 7                                             Yes Mam   Neutral
# 8      I will send 2 abstracts for u to start working   Neutral
# 9                                            Yeah mam   Neutral
# 10                   Give me the list that u have too   Neutral
# 11   Send me cbe office address and phone number I...   Neutral
# 12    Yeah Mam within Evening I will forward you mam.   Neutral
# 13   Tomorrow I have to visit the office.yet not I...   Neutral
# 14                                                 ok   Neutral
# 15   send the details of office location once u ge...   Neutral
# 16   Sure mam. Soon I will share details with you mam   Neutral
# 17   I have read the Abstract mam. We can do mam. ...   Neutral
# 18   I think Vignesh has the data set will ask him...   Neutral
# 19                          I have sent the abstracts   Neutral
# 20                                             Ok mam   Neutral
# 21   I have read both the abstract mam. We can do ...   Neutral
# 22   Yes we need to ya about amount and all other ...   Neutral
# 23                                          Sure mam.   Neutral
# 24                                  Shall I call mam?   Neutral
# 25         Hi I was at church couldn’t take your call   Neutral
# 26                                         It's k mam   Neutral
# 27   Just to know the tomorrow plan mam.will see t...   Neutral
# 28                    Mam can u send Vignesh number??   Neutral
# 29           Vignesh ML Infoziant.vcf (file attached)   Neutral
# 30                           I was in a meeting sorry   Neutral
# 31                                    Can I cal u mam   Neutral
# 32   Waiting for u r finalization of rates for our...   Neutral
# 33   If we finiliaze I can work with full involvem...   Neutral
# 34   So what ever may be ..if you think your are c...   Neutral
# 35                           You deleted this message   Neutral
# 36                                     Do the needful   Neutral
# 37   No ma please hold I am in a hot meeting with ...   Neutral
# 38                                     Ok mam thank u   Neutral
# 39   Ramisha we need to talk today i will call u a...   Neutral
# 40     Be ready to discuss about the ML titles u have   Neutral
# 41                                           Okay mam   Neutral
# 42                                                 ok   Neutral
# 43                                    Mam are u free?   Neutral
# 44   Am at church can call very late or tomorrow only   Neutral
# 45   Kk mam. I will ask Arun brother. Small doubt ...   Neutral
# 46                                             Hi mam   Neutral
# 47                                   Any updates mam?   Neutral
# 48     U might have to start on the WhatsApp analysis   Neutral
# 49            There is one project that got committed   Neutral
# 50                                           Kk mam👍🏻   Neutral>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example dataset with sentiment classification
data_Senti = pd.DataFrame({
    'chat': dataset['chat'],   # Original text
    'Sentiment': pos           # Sentiment classifications: Positive, Negative, Neutral
})

# Count the number of occurrences for each sentiment
sentiment_counts = data_Senti['Sentiment'].value_counts()
print(sentiment_counts)
# Out:
# Sentiment
# Neutral    48
# 48          1
# 2           1
# Name: count, dtype: int64

# %%
from wordcloud import WordCloud

# Generate a word cloud for Neutral sentiments
positive_text = " ".join(data_Senti[data_Senti['Sentiment'] == 'Neutral']['chat'])
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(positive_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud for Neutral Sentiments")
plt.show()

# %%
print(data_Senti.columns)
# Out:
# Index(['chat', 'Sentiment'], dtype='object')

# %%
# Pie chart
plt.figure(figsize=(8, 6))
sentiment_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['green', 'blue', 'red'])
plt.title("Sentiment Analysis Results")
plt.ylabel("")  # Hide the y-axis label for a cleaner pie chart
plt.show()

# %%
# Bar chart
plt.figure(figsize=(8, 6))
sentiment_counts.plot(kind='bar', color=['green', 'blue', 'red'], alpha=0.7)
plt.title("Sentiment Analysis Results")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %%
# Save DataFrame as a text file
#data_Senti.to_csv('preprocessed_chat.txt', sep='\t', index=False, header=True)

# %%
import pandas as pd

# Load Data
#df = pd.read_csv("processed.csv", header=None, on_bad_lines='skip', encoding='utf-8')
df = pd.read_csv("processed.csv")

# Inspect columns
print("Columns before renaming:", df.columns)

# Assign appropriate column names
#df.columns = ['date', 'time', 'name', 'chat', 'col5', 'col6', 'col7', 'col8', 'col9', 'col10', 'col11']

# Select the relevant 4 columns
columns_to_keep = ['Date', 'Time', 'Name', 'Text']
df2 = df[columns_to_keep]
# Clean date and time columns
df2['Date'] = df['Date'].str.strip()
df2['Time'] = df['Time'].str.strip()

# Combine date and time into timestamp
df2['timestamp'] = pd.to_datetime(df2['Date'] + ' ' + df2['Time'], format='%d/%m/%y %I:%M %p', errors='coerce')
df2 = df2.dropna(subset=['timestamp'])
df2.head()
# Out:
# Columns before renaming: Index(['Date', 'Time', 'Name', 'Text', 'scores', 'compound', 'Negtive',
#        'Postive', 'Neutral', 'comp_score', 'Topic'],
#       dtype='object')
# C:\Users\Prabhu\AppData\Local\Temp\ipykernel_8384\535782308.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date'] = df['Date'].str.strip()
# C:\Users\Prabhu\AppData\Local\Temp\ipykernel_8384\535782308.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Time'] = df['Time'].str.strip()
# C:\Users\Prabhu\AppData\Local\Temp\ipykernel_8384\535782308.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['timestamp'] = pd.to_datetime(df2['Date'] + ' ' + df2['Time'], format='%d/%m/%y %I:%M %p', errors='coerce')
#       Date      Time           Name  \
# 0  10/4/20   9:40 PM     Suganya tn
# 1  10/4/20  11:18 PM     Suganya tn
# 2  10/5/20   5:31 AM   hameedfemina
# 3  10/5/20   5:32 AM   hameedfemina
# 4  10/5/20   5:32 AM   hameedfemina
#
#                                                 Text           timestamp
# 0                       Is that yoga class good Femi 2020-04-10 21:40:00
# 1   Preksha from jeeva parivardhanam yoga only u ... 2020-04-10 23:18:00
# 2                                        89044 91142 2020-05-10 05:31:00
# 3                       This person name is Shashank 2020-05-10 05:32:00
# 4                     He s also one of the organizer 2020-05-10 05:32:00

# %%
print(df2.columns)  # Displays the column names
# Out:
# Index(['Date', 'Time', 'Name', 'Text', 'timestamp'], dtype='object')

# %%
print(df2.head())
# Out:
#       Date      Time           Name  \
# 0  10/4/20   9:40 PM     Suganya tn
# 1  10/4/20  11:18 PM     Suganya tn
# 2  10/5/20   5:31 AM   hameedfemina
# 3  10/5/20   5:32 AM   hameedfemina
# 4  10/5/20   5:32 AM   hameedfemina
#
#                                                 Text           timestamp
# 0                       Is that yoga class good Femi 2020-04-10 21:40:00
# 1   Preksha from jeeva parivardhanam yoga only u ... 2020-04-10 23:18:00
# 2                                        89044 91142 2020-05-10 05:31:00
# 3                       This person name is Shashank 2020-05-10 05:32:00
# 4                     He s also one of the organizer 2020-05-10 05:32:00

# %%
df2
# Out:
#         Date      Time           Name  \
# 0    10/4/20   9:40 PM     Suganya tn
# 1    10/4/20  11:18 PM     Suganya tn
# 2    10/5/20   5:31 AM   hameedfemina
# 3    10/5/20   5:32 AM   hameedfemina
# 4    10/5/20   5:32 AM   hameedfemina
# ..       ...       ...            ...
# 190  5/10/22   6:32 PM   hameedfemina
# 195   1/1/23   1:36 PM   hameedfemina
# 196   1/1/23   6:30 PM     Suganya tn
# 207   4/1/23  11:03 PM     Suganya tn
# 208   4/2/23   4:46 AM   hameedfemina
#
#                                                   Text           timestamp
# 0                         Is that yoga class good Femi 2020-04-10 21:40:00
# 1     Preksha from jeeva parivardhanam yoga only u ... 2020-04-10 23:18:00
# 2                                          89044 91142 2020-05-10 05:31:00
# 3                         This person name is Shashank 2020-05-10 05:32:00
# 4                       He s also one of the organizer 2020-05-10 05:32:00
# ..                                                 ...                 ...
# 190                                                  😘 2022-10-05 18:32:00
# 195                                Happy new year Sugu 2023-01-01 13:36:00
# 196                                Happy new year Femi 2023-01-01 18:30:00
# 207                   Hey super. In which they got ma? 2023-01-04 23:03:00
# 208                                          Badminton 2023-02-04 04:46:00
#
# [78 rows x 5 columns]

# %%
def flirt_analysis(messages):
    flirt_keywords = ['love', 'babe', 'darling', 'sweetheart', 'kiss', 'cute', 'beautiful', 'sexy']
    vectorizer = CountVectorizer(vocabulary=flirt_keywords, lowercase=True)
    flirt_scores = vectorizer.fit_transform(messages['Text']).sum(axis=1)
    messages['flirt_count'] = flirt_scores
    return messages

df2 = flirt_analysis(df2)

# %%
# Count messages per user
talkative_counts = df2['Name'].value_counts()
less_talkative = talkative_counts.idxmin()
less_talkative
# Out:
# ' Suganya tn'

# %%
# Most active date and time
#most_active_date = df2['Date'].value_counts().idxmax()
#df2['hour'] = df['timestamp'].dt.hour
#most_active_hour = df2['hour'].value_counts().idxmax()
df2['hour'] = df2['timestamp'].dt.hour
most_active_hour = df2['hour'].value_counts().idxmax()
print("Most active hour:", most_active_hour)
# Out:
# Most active hour: 8

# %%
# Media count
df2['is_media'] = df2['Text'].str.contains('<Media omitted>', na=False)
media_count = df2[df2['is_media']]['Name'].value_counts()
print(media_count)
# Out:
# Name
# hameedfemina    2
# Name: count, dtype: int64

# %%
# Missed calls count
df2['is_missed_call'] = df2['Text'].str.contains('Missed voice call|Missed video call', case=False, na=False)
missed_calls = df2[df2['is_missed_call']]['Name'].value_counts()
print(missed_calls)
# Out:
# Series([], Name: count, dtype: int64)

# %%
print("Flirt Messages:\n", df2[df2['flirt_count'] > 0])
print("Less Talkative User:", less_talkative)
print("Most Active Date:", most_active_date)
print("Most Active Hour:", most_active_hour)
print("Media Count:\n", media_count)
print("Missed Calls Count:\n", missed_calls)
# Out:
# Flirt Messages:
#  Empty DataFrame
# Columns: [Date, Time, Name, Text, timestamp, flirt_count, hour, is_media, is_missed_call]
# Index: []
# Less Talkative User:  Suganya tn
# Most Active Date: 5/8/21
# Most Active Hour: 8
# Media Count:
#  Name
# hameedfemina    2
# Name: count, dtype: int64
# Missed Calls Count:
#  Series([], Name: count, dtype: int64)
